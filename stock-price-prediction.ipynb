# %% [markdown]
# # TATA Stock Price Prediction
#
# ### Annisa Nurul Azhar - 23519025

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
# Out:
# Using TensorFlow backend.

# %%
dataset_train = pd.read_csv('datasets/NSE-TATAGLOBAL.csv')
training_set = dataset_train.iloc[:, 1:2].values

# %%
dataset_train.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
X_train = []
y_train = []
for i in range(60, 2035):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i,0])
X_train, y_train = np.array(X_train), np.array(y_train)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
regressor = Sequential()

regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

regressor.add(Dense(units = 1))

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# WARNING:tensorflow:From /Users/bukalapak/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /Users/bukalapak/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 0.0085
# Epoch 2/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 0.0025
# Epoch 3/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 0.0023
# Epoch 4/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 0.0022
# Epoch 5/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 0.0020
# Epoch 6/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 0.0022
# Epoch 7/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 0.0021
# Epoch 8/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 0.0017
# Epoch 9/100
# 1975/1975 [==============================] - 6s 3ms/step - loss: 0.0020
# Epoch 10/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 0.0018
# Epoch 11/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 0.0016
# Epoch 12/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 0.0015
# Epoch 13/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 0.0016
# Epoch 14/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 0.0014
# Epoch 15/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 0.0014
# Epoch 16/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 0.0015
# Epoch 17/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 0.0015
# Epoch 18/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 0.0012
# Epoch 19/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 0.0012
# Epoch 20/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 0.0012
# Epoch 21/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 0.0012
# Epoch 22/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 0.0013
# Epoch 23/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 0.0012
# Epoch 24/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 0.0012
# Epoch 25/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 9.5190e-04
# Epoch 26/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 0.0012
# Epoch 27/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 0.0012
# Epoch 28/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 0.0011
# Epoch 29/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 0.0011
# Epoch 30/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 9.2493e-04
# Epoch 31/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 9.4293e-04
# Epoch 32/100
# 1975/1975 [==============================] - 6s 3ms/step - loss: 9.4539e-04
# Epoch 33/100
# 1975/1975 [==============================] - 6s 3ms/step - loss: 0.0010
# Epoch 34/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 9.2860e-04A:
# Epoch 35/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 0.0011
# Epoch 36/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 7.7375e-04
# Epoch 37/100
# 1975/1975 [==============================] - 6s 3ms/step - loss: 8.6151e-04
# Epoch 38/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 8.7540e-04
# Epoch 39/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 8.5045e-04
# Epoch 40/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 8.1837e-04
# Epoch 41/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 8.7664e-04
# Epoch 42/100
# 1975/1975 [==============================] - 6s 3ms/step - loss: 7.8989e-04
# Epoch 43/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 7.2902e-04
# Epoch 44/100
# 1975/1975 [==============================] - 6s 3ms/step - loss: 8.6290e-04
# Epoch 45/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 8.2019e-04
# Epoch 46/100
# 1975/1975 [==============================] - 6s 3ms/step - loss: 7.5135e-04
# Epoch 47/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 7.7108e-04
# Epoch 48/100
# 1975/1975 [==============================] - 6s 3ms/step - loss: 7.5388e-04
# Epoch 49/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 8.2921e-04A: 0s - loss: 8.1727e-
# Epoch 50/100
# 1975/1975 [==============================] - 8s 4ms/step - loss: 8.0132e-04
# Epoch 51/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 7.6052e-04
# Epoch 52/100
# 1975/1975 [==============================] - 6s 3ms/step - loss: 6.9983e-04
# Epoch 53/100
# 1975/1975 [==============================] - 6s 3ms/step - loss: 8.1610e-04
# Epoch 54/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 6.7745e-04
# Epoch 55/100
# 1975/1975 [==============================] - 6s 3ms/step - loss: 8.2117e-04
# Epoch 56/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 6.6250e-04
# Epoch 57/100
# 1975/1975 [==============================] - 6s 3ms/step - loss: 7.5825e-04
# Epoch 58/100
# 1975/1975 [==============================] - 8s 4ms/step - loss: 6.8440e-04
# Epoch 59/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 6.7415e-04
# Epoch 60/100
# 1975/1975 [==============================] - 6s 3ms/step - loss: 6.2113e-04
# Epoch 61/100
# 1975/1975 [==============================] - 33s 17ms/step - loss: 6.6718e-04
# Epoch 62/100
# 1975/1975 [==============================] - 6s 3ms/step - loss: 6.7861e-04
# Epoch 63/100
# 1975/1975 [==============================] - 7s 3ms/step - loss: 6.5678e-04
# Epoch 64/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 6.5328e-04
# Epoch 65/100
# 1975/1975 [==============================] - 21s 11ms/step - loss: 6.8833e-04
# Epoch 66/100
# 1975/1975 [==============================] - 6s 3ms/step - loss: 7.3835e-04
# Epoch 67/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 6.0827e-04
# Epoch 68/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 6.3308e-04
# Epoch 69/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 6.2453e-04
# Epoch 70/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 7.0181e-04
# Epoch 71/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 6.2143e-04
# Epoch 72/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 6.1730e-04
# Epoch 73/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 6.3380e-04
# Epoch 74/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 6.4807e-04
# Epoch 75/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 6.8565e-04
# Epoch 76/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 6.9669e-04
# Epoch 77/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 7.2621e-04
# Epoch 78/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 6.7454e-04
# Epoch 79/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 5.9477e-04A: 0s - los
# Epoch 80/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 6.9333e-04
# Epoch 81/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 6.5776e-04
# Epoch 82/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 5.7578e-04
# Epoch 83/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 6.1590e-04
# Epoch 84/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 6.4347e-04
# Epoch 85/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 6.5730e-04
# Epoch 86/100
# 1975/1975 [==============================] - 5s 3ms/step - loss: 6.3731e-04
# Epoch 87/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 6.0805e-04
# Epoch 88/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 6.4472e-04
# Epoch 89/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 7.0109e-04
# Epoch 90/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 4.8219e-04
# Epoch 91/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 6.0164e-04
# Epoch 92/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 5.9678e-04A: 2s - lo - ETA:
# Epoch 93/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 6.1915e-04
# Epoch 94/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 5.6748e-04
# Epoch 95/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 5.9012e-04
# Epoch 96/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 6.5837e-04
# Epoch 97/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 6.2709e-04
# Epoch 98/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 6.2689e-04
# Epoch 99/100
# 1975/1975 [==============================] - 5s 2ms/step - loss: 5.9855e-04
# Epoch 100/100
# 1975/1975 [==============================] - 4s 2ms/step - loss: 5.8252e-04

# %%
dataset_test = pd.read_csv('tatatest.csv')
dataset_test.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-6ec77c115ac7> in <module>
# ----> 1 dataset_test = pd.read_csv('tatatest.csv')
#       2 dataset_test.head()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'tatatest.csv' does not exist: b'tatatest.csv'

# %%
dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
y_test = []
for i in range(60, 76):
    X_test.append(inputs[i-60:i, 0])
    y_test.append(inputs[i,0])
X_test = np.array(X_test)
real_stock_price = np.array(y_test)
real_stock_price = sc.inverse_transform(real_stock_price.reshape(-1,1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
plt.plot(real_stock_price, color = 'black', label = 'TATA Stock Price')
plt.plot(predicted_stock_price, color = 'green', label = 'Predicted TATA Stock Price')
plt.title('TATA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('TATA Stock Price')
plt.legend()
plt.show()
